# %% [markdown]
# ## **Librerias**

# %%
import tensorflow as tf
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns   
import imghdr
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from tensorflow.keras.metrics import Precision,Recall,Accuracy

# %% [markdown]
# GPU TEST 🧪🧪

# %%
gpus = tf.config.experimental.list_physical_devices("GPU") #Se usa para evitar error por falta de memoria
for gpu in gpus:
    tf.config.experimental.set_memory_growth(gpu,True)
tf.config.list_physical_devices("GPU")
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## **Creacion Data Set 💾**

# %%
Data_dir = './Data'
Data_train = './Data/train'
img_ext = ['png']

# %%
sub_carpetas = os.listdir(os.path.join(Data_dir,'train')) 
sub_carpetas
# Out:
# ['ELBOW', 'FINGER', 'FOREARM', 'HAND', 'HUMERUS', 'SHOULDER', 'WRIST']

# %%
os.listdir(Data_train)
# Out:
# ['ELBOW', 'FINGER', 'FOREARM', 'HAND', 'HUMERUS', 'SHOULDER', 'WRIST']

# %%
for img_class in os.listdir(Data_train):
    for image in os.listdir(os.path.join(Data_train,img_class)):
        image_path = os.path.join(Data_train,img_class,image)
        try:
            img = cv2.imread(image_path)   
            tip = imghdr.what(image_path)
            if tip not in img_ext:
                print('Formato no permitido'.format(image_path))
                os.remove(image_path)
        except Exception as e:  
            print("PRoblema con la imagen".format(image_path))

# %%
# for img_class in os.listdir(Data_train):
#     for image in os.listdir(os.path.join(Data_train,img_class)):
#         print(image)

# %%
data = tf.keras.utils.image_dataset_from_directory('./Data/train',image_size=(128,128),batch_size=128)
# Out:
# Found 840 files belonging to 7 classes.

# %%
data_iterador = data.as_numpy_iterator()
data_iterador

# %%
batch = data_iterador.next()
# batch[0].shape
# Esta seccion me permite tener un batch de imagenes que pueden ser traidas a memorias 
# cuando se requiera usar un bath, en este caso hay un bath de 128 imagenes, represenatadas en un arreglo de numpy

# %%
labels_aux = {0: 'Elbow' ,
              1: 'Finger',
              2: 'Forearm',
              3: 'Hand',
              4: 'Humerus',
              5: 'Shoulder',
              6: 'Wirst'}

# %% [markdown]
# ## **Procesar Data Set 🏭**

# %%
data = data.map(lambda x,y: (x/255,y))
data # Se hace un escalado de los datos
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
scaled_iterador = data.as_numpy_iterator()
print(f'Valor mininmo {scaled_iterador.next()[0].min()}')
print(f'Valor maximo {scaled_iterador.next()[0].max()}')
# Out:
# Valor mininmo 0.0
# Valor maximo 1.0

# %%
batch = scaled_iterador.next()

# %%
fig, ax = plt.subplots(ncols=4,figsize=(20,20))
for idx,img in enumerate(batch[0][:4]):
    ax[idx].imshow(img)
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# ### **SPLIT DATA 🪓**

# %%
train_size = int(len(data)*.7)
val_size = int(len(data)*.2)+1
test_size = int(len(data)*.1)+1
print(f'train: {train_size}',f'test: {test_size}',f'val: {val_size}')
print(f'Leng Data: {len(data)}')
# Out:
# train: 4 test: 1 val: 2
# Leng Data: 7

# %%
train = data.take(train_size)
val = data.skip(train_size).take(val_size)
test = data.skip(train_size+val_size).take(test_size)

# %% [markdown]
# ## **Modelo 📸**

# %% [markdown]
# ### **Contruir Modelo 🔨**

# %%
model = Sequential()

model.add(Conv2D(32,(3,3),1, activation="relu", input_shape=(128,128,3)))
model.add(MaxPooling2D())

model.add(Conv2D(64,(3,3),1,activation="relu"))
model.add(MaxPooling2D())

model.add(Conv2D(32,(3,3),1,activation="relu"))
model.add(MaxPooling2D())

model.add(Flatten())    
model.add(Dense(128, activation='relu'))
model.add(Dense(7,activation='softmax'))

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 28, 28, 32)        18464
#
#  max_pooling2d_2 (MaxPooling  (None, 14, 14, 32)       0
#  2D)
#
#  flatten (Flatten)           (None, 6272)              0
#
#  dense (Dense)               (None, 128)               802944
#
#  dense_1 (Dense)             (None, 7)                 903
#
# =================================================================
# Total params: 841,703
# Trainable params: 841,703
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### **Entrenar Modelo 💪**

# %%
logdir = './logs'

# %%
callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %%
hist = model.fit(train, epochs=20, validation_data=val, callbacks=[callback])
# Out:
# Epoch 1/20
# 4/4 [==============================] - 3s 116ms/step - loss: 1.9478 - accuracy: 0.1699 - val_loss: 1.9270 - val_accuracy: 0.1875
# Epoch 2/20
# 4/4 [==============================] - 0s 91ms/step - loss: 1.9067 - accuracy: 0.2070 - val_loss: 1.8563 - val_accuracy: 0.3047
# Epoch 3/20
# 4/4 [==============================] - 0s 94ms/step - loss: 1.8063 - accuracy: 0.3379 - val_loss: 1.6866 - val_accuracy: 0.3672
# Epoch 4/20
# 4/4 [==============================] - 0s 88ms/step - loss: 1.6041 - accuracy: 0.3906 - val_loss: 1.4728 - val_accuracy: 0.4336
# Epoch 5/20
# 4/4 [==============================] - 0s 93ms/step - loss: 1.4226 - accuracy: 0.5078 - val_loss: 1.3021 - val_accuracy: 0.5156
# Epoch 6/20
# 4/4 [==============================] - 0s 88ms/step - loss: 1.3208 - accuracy: 0.5176 - val_loss: 1.1845 - val_accuracy: 0.5664
# Epoch 7/20
# 4/4 [==============================] - 0s 89ms/step - loss: 1.2323 - accuracy: 0.5586 - val_loss: 1.0687 - val_accuracy: 0.6367
# Epoch 8/20
# 4/4 [==============================] - 0s 93ms/step - loss: 1.1088 - accuracy: 0.6211 - val_loss: 1.0319 - val_accuracy: 0.6562
# Epoch 9/20
# 4/4 [==============================] - 0s 90ms/step - loss: 1.0243 - accuracy: 0.6426 - val_loss: 0.9168 - val_accuracy: 0.6953
# Epoch 10/20
# 4/4 [==============================] - 0s 91ms/step - loss: 0.8922 - accuracy: 0.6914 - val_loss: 0.8008 - val_accuracy: 0.7539
# Epoch 11/20
# 4/4 [==============================] - 0s 92ms/step - loss: 0.8109 - accuracy: 0.7188 - val_loss: 0.8032 - val_accuracy: 0.7031
# Epoch 12/20
# 4/4 [==============================] - 0s 90ms/step - loss: 0.7305 - accuracy: 0.7422 - val_loss: 0.6881 - val_accuracy: 0.7656
# Epoch 13/20
# 4/4 [==============================] - 0s 92ms/step - loss: 0.5868 - accuracy: 0.8066 - val_loss: 0.5736 - val_accuracy: 0.8125
# Epoch 14/20
# 4/4 [==============================] - 0s 93ms/step - loss: 0.5433 - accuracy: 0.8145 - val_loss: 0.5151 - val_accuracy: 0.8125
# Epoch 15/20
# 4/4 [==============================] - 0s 94ms/step - loss: 0.4796 - accuracy: 0.8438 - val_loss: 0.3533 - val_accuracy: 0.9180
# Epoch 16/20
# 4/4 [==============================] - 0s 100ms/step - loss: 0.4104 - accuracy: 0.8848 - val_loss: 0.3786 - val_accuracy: 0.8789
# Epoch 17/20
# 4/4 [==============================] - 0s 91ms/step - loss: 0.3312 - accuracy: 0.9062 - val_loss: 0.2313 - val_accuracy: 0.9336
# Epoch 18/20
# 4/4 [==============================] - 0s 94ms/step - loss: 0.2512 - accuracy: 0.9277 - val_loss: 0.2497 - val_accuracy: 0.9414
# Epoch 19/20
# 4/4 [==============================] - 0s 95ms/step - loss: 0.2190 - accuracy: 0.9395 - val_loss: 0.2198 - val_accuracy: 0.9531
# Epoch 20/20
# 4/4 [==============================] - 0s 94ms/step - loss: 0.1891 - accuracy: 0.9668 - val_loss: 0.1758 - val_accuracy: 0.9492

# %% [markdown]
# ### **Rendimiento ⚙️**

# %%
fig = plt.figure(figsize=(8,4))
plt.plot(hist.history['loss'],color='teal',label='Tain loss')
plt.plot(hist.history['val_loss'],color='orange',label='Validation loss')
fig.suptitle('Loss',fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
fig = plt.figure(figsize=(8,4))
plt.plot(hist.history['accuracy'],color='teal',label='Train accuracy')
plt.plot(hist.history['val_accuracy'],color='orange',label='Validation accuracy')
fig.suptitle('accuracy',fontsize=20)
plt.legend(loc='upper left')
plt.show()

# %%
pre = Precision()
re = Recall()
acc = Accuracy()

# %%
pre = Precision()
re = Recall()
acc = Accuracy()

for batch in test.as_numpy_iterator(): 
    X, y = batch
    y = tf.one_hot(y, depth=7)
    yhat = model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
precision = round(pre.result().numpy(), 2)
recall = round(re.result().numpy(), 2)
accuracy = round(acc.result().numpy(), 2)

print(f"Resultados:\n Precision: {precision}\n ReCall: {recall}\n Exactitud: {accuracy}")
# Out:
# Resultados:
#  Precision: 0.9700000286102295
#  ReCall: 0.9599999785423279
#  Exactitud: 0.0

# %% [markdown]
# ## **Prediccion 🔮**

# %%
def carga_imagen(img_test_path):    
    img = cv2.imread(img_test_path)
    resize = tf.image.resize(img, (128, 128))
    plt.imshow(resize.numpy().astype(int))
    plt.show()
    return resize

# %%
img_test_path = './pngtree-xray-image-of-forearm-ap-showing-fractured-shaft-of-ulnar-bone-png-image_13365053.png'
imagen_1 = carga_imagen(img_test_path)

# %%
def prediccion(imagen,model):   
    y_hat = model.predict(np.expand_dims(imagen/255,0))
    max_index = np.argmax(y_hat)
    max_index
    labels_aux = {0: 'Codo',
                  1: 'Dedo',
                  2: 'Antebrazo',
                  3: 'Mano',
                  4: 'Húmero',
                  5: 'Hombro',
                  6: 'Muñeca'}

    if max_index in labels_aux:
        prediccion_final = labels_aux[max_index]
    return print(f'La Radiografia corresponde a una fractura de {prediccion_final}')

# %%
prediccion(imagen_1)
# Out:
# La Radiografia corresponde a una fractura de Codo

# %% [markdown]
# ## **Cargar Modelo ☁️**

# %%
model.save(os.path.join('modelos','Clasificador_Fracutra.h5'))

# %%
from tensorflow.keras.models import load_model
new_model = load_model('./modelos/Clasificador_Fracutra.h5')

# %%
img_test_path = './Imagenes_prueba/muneca.png'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Muñeca

# %%
img_test_path = './Imagenes_prueba/codo.webp'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Codo

# %%
img_test_path = './Imagenes_prueba/humero.jpeg'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Húmero

# %%
img_test_path = './Imagenes_prueba/hombro.jpeg'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Hombro

# %%
img_test_path = './Imagenes_prueba/mano.jpg'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Mano

# %%
img_test_path = './Imagenes_prueba/Brazo.jpeg'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Antebrazo

# %%
img_test_path = './Imagenes_prueba/dedo.jpeg'
imagen_2 = carga_imagen(img_test_path)
prediccion(imagen_2,new_model)
# Out:
# La Radiografia corresponde a una fractura de Dedo
